# %% [markdown]
# # DATA101 Critique Activity: Perception & Color + Reading Charts
#
# **Instructor:** Marc Reyes (marc.reyes@dlsu.edu.ph)
#
# You will practice *reading* and *critiquing* real visualizations using a repeatable workflow:
#
# **Claim → Data → Encodings → Perception/Color → Conclusion → Redesign**

# %% [markdown]
# ## Learning Objectives
#
# By the end of this notebook, you should be able to:
#
# - Identify a chart’s **main claim** and the **task** it supports (compare, rank, detect, etc.).
# - Audit **data + units** (counts vs rates, denominators, missingness).
# - Diagnose misleading **encodings** (3D, truncated axes, area-based comparisons).
# - Evaluate **color mapping + accessibility** (sequential/diverging/categorical, CVD-safe, contrast).
# - Propose a **concrete redesign** that better matches the task.

# %% [markdown]
# ## Group Information (edit this cell)
#
# | Group # | Members (Last, First) |
# |---:|---|
# |  |  |
# |  |  |
# |  |  |
# |  |  |
# |  |  |

# %% [markdown]
# ## What To Submit
#
# Submit the completed notebook with:
#
# - Your critique notes for **all case studies**
# - A completed **summary table**
# - A short set of **rules of thumb** you will use in your own work
# - A **References (APA)** section

# %% [markdown]
# ## Environment Setup (if needed)
#
# If your JupyterHub environment is missing packages (`matplotlib` is used here for optional helpers), run the install cell once.
# If everything imports successfully, you can skip it.

# %%
# Install dependencies (run once if needed)
# If this notebook is opened from the `notebooks/` folder, it will use `notebooks/requirements.txt`.
# If you moved the notebook elsewhere, adjust the path accordingly.
# !pip install -r requirements.txt

# %%
# Setup
from __future__ import annotations

from pathlib import Path

from IPython.display import Image, display

ASSET_DIR = Path("assets/perception-color")


def show_image(filename: str, *, width: int = 1100) -> None:
    # Display a local image asset at a readable size.
    path = ASSET_DIR / filename
    if not path.exists():
        raise FileNotFoundError(
            f"Missing asset: {path}. Make sure you have the repo's `notebooks/assets/` folder."
        )
    display(Image(filename=str(path), width=width))

# %% [markdown]
# ## Chart Reading Checklist (Use for Every Case)
#
# Use this checklist to structure your critique. You don’t need to answer every sub-question, but your notes should show the logic.
#
# 1. **Title / Claim:** What is the chart trying to convince you is true?
# 2. **Data:** What is measured? What’s missing? What’s the unit of analysis?
# 3. **Units:** Counts vs rates vs %? Is a **denominator** needed?
# 4. **Axes / Scale:** Baseline (0?), truncation, log scale, binning, smoothing.
# 5. **Encoding:** Position vs length vs area vs color — is the channel appropriate for the task?
# 6. **Grouping / Context:** Aggregation choices, categories, labeling, legend hunting.
# 7. **Color + Accessibility:** Sequential/diverging/categorical? Perceptual order? CVD-safe? Enough contrast?
# 8. **Conclusion:** Does the chart support the claim? What redesign would make it more defensible?

# %% [markdown]
# # Case Study 1 — Hurricane “Cone of Uncertainty” (Misread Uncertainty)
#
# This is one of the most widely shared public weather graphics. It communicates uncertainty, but many viewers misread what the cone means.
#
# **Source (APA):**
# National Hurricane Center. (n.d.). *Tropical cyclone track and watches/warnings: Cone of uncertainty example* [Image]. National Oceanic and Atmospheric Administration. Retrieved January 24, 2026, from https://www.nhc.noaa.gov/images/cone_5day_with_wind.png

# %%
show_image("noaa_hurricane_cone.png", width=1100)

# %% [markdown]
# ## Your Critique (edit this cell)
#
# - **Claim (1 sentence):**
# - **What the cone *does* mean (in your words):**
# - **What people *often think* it means (the common misread):**
# - **Where uncertainty is shown well / poorly (be specific):**
# - **Color + symbols:** What is categorical vs quantitative here? What is hard to decode?
# - **What would you change (at least 3 fixes):**
# - **Redesign proposal:** Sketch a better version (what stays, what changes, what you would label).

# %% [markdown]
# # Case Study 2 — NASA Global Temperature Anomalies (Diverging Color + Baseline)
#
# This map is visually compelling, but it’s easy to misunderstand what is being encoded (and what the baseline means).
#
# **Source (APA):**
# NASA Science. (2025). *2025 global temperature anomalies (GISTEMP)* [Image]. NASA. Retrieved January 24, 2026, from https://assets.science.nasa.gov/dynamicimage/assets/science/esd/indicators/global-temperature/GISTEMP_Map_HD_2025.webp

# %%
show_image("nasa_gistemp_2025.jpg", width=1100)

# %% [markdown]
# ## Your Critique (edit this cell)
#
# - **Claim (1 sentence):**
# - **What is being mapped (be precise):** Is this *absolute temperature* or an *anomaly*? Compared to what?
# - **Color scale type:** sequential, diverging, or categorical? What does the midpoint represent?
# - **Common misread:** What might a casual viewer conclude incorrectly?
# - **Accessibility:** How would you make the color mapping safer (contrast, labels, legend, CVD)?
# - **What would you change (at least 3 fixes):**
# - **Redesign proposal:** Keep the story, but improve interpretation.

# %% [markdown]
# # Case Study 3 — U.S. Drought Monitor (Categorical Map + Threshold Effects)
#
# This weekly map is used by government and media. The colors are meaningful categories—but maps can still mislead.
#
# **Source (APA):**
# National Drought Mitigation Center. (2026, January 22). *U.S. Drought Monitor (January 20, 2026)* [Map]. University of Nebraska–Lincoln. https://droughtmonitor.unl.edu/data/png/20260120/20260120_usdm.png

# %%
show_image("usdm_20260120.jpg", width=1100)

# %% [markdown]
# ## Your Critique (edit this cell)
#
# - **Claim (1 sentence):**
# - **What the colors represent:** Are these ordered categories? Are the thresholds clear?
# - **What a viewer might misread:** (Examples: “most of the U.S. is drought”, “this is continuous heatmap data”, etc.)
# - **Map pitfalls:** What does *area* imply here, and what is missing (population, agriculture, water use, etc.)?
# - **Color critique:** Is the palette legible and ordered? What about grayscale/CVD?
# - **What would you change (at least 3 fixes):**
# - **Redesign proposal:** Choose one better approach (e.g., add affected-population panel, small multiples over time, uncertainty notes, annotations).

# %% [markdown]
# # Case Study 4 — CDC FluView (Missing Data ≠ Zero + Visual Emphasis)
#
# This chart includes a *shaded region* and a bright line. It’s a realistic example of how charts can be read incorrectly when missingness and status aren’t obvious.
#
# **Source (APA):**
# Centers for Disease Control and Prevention. (2026). *Long-term care influenza hospitalization rate among residents, reported to NHSN, national summary, 2025–2026 season* [Chart]. CDC FluView. Retrieved January 24, 2026, from https://www.cdc.gov/fluview/media/images/2026/01/LTCF02.gif

# %%
show_image("cdc_ltcf_influenza_rate.png", width=1100)

# %% [markdown]
# ## Your Critique (edit this cell)
#
# - **Claim (1 sentence):**
# - **Axes + units:** What is the y-axis and what does the unit imply?
# - **What does the gray region mean?** Why can it be misread as “drop” or “increase”?
# - **Color + emphasis:** What does the bright line make you focus on? Is that appropriate?
# - **What would you change (at least 3 fixes):**
# - **Redesign proposal:** How would you communicate status (preliminary vs final) more clearly?

# %% [markdown]
# # Case Study 5 — Nightingale Polar Area Diagram (Area Encoding in the Wild)
#
# This is a historically famous public health graphic. It’s powerful—but the encoding is easy to misread.
#
# **Source (APA):**
# Wellcome Collection. (n.d.). *Army in the East* [Chart image]. In *Mortality of the British army: at home and abroad, and during the Russian war, as compared with the mortality of the civil population in England; illustrated by tables and diagrams* (Wellcome Collection item b20452433, plate b20452433_0050). Retrieved January 24, 2026, from https://wellcomecollection.org/works/gxtkyqp8

# %%
show_image("wellcome_nightingale_polar_area.jpg", width=1100)

# %% [markdown]
# ## Your Critique (edit this cell)
#
# - **Claim (1–2 sentences):**
# - **What task(s) this supports well:**
# - **What task(s) it makes hard (be specific):**
# - **Encoding critique:** What is encoded by **angle**, **radius**, and/or **area**? Why can that mislead?
# - **Color critique:** What does color represent here? Is the legend discoverable and unambiguous?
# - **Accessibility:** If a viewer can’t rely on color, what would you add?
# - **Redesign proposal:** How would you show the same story with a more readable encoding?

# %% [markdown]
# # Synthesis
#
# ## Rules of Thumb (edit this cell)
#
# Write concise rules you can reuse when designing and critiquing charts.
#
# ### Color (5 rules)
# 1.
# 2.
# 3.
# 4.
# 5.
#
# ### Reading charts (5 rules)
# 1.
# 2.
# 3.
# 4.
# 5.
#
# ### One workflow you will repeat
# (Example format: *state the claim → list tasks → check units/denominators → verify axes → validate encodings → check color/accessibility → revise*)

# %% [markdown]
# ## Summary Table (edit this cell)
#
# | Case | Main pitfall | Why it misleads | Best fix | Proposed redesign |
# |---:|---|---|---|---|
# | 1 |  |  |  |  |
# | 2 |  |  |  |  |
# | 3 |  |  |  |  |
# | 4 |  |  |  |  |
# | 5 |  |  |  |  |

# %% [markdown]
# ## Rubric (20 points)
#
# - **Case critiques (15 pts total; 3 pts each × 5 cases):**
#   - (1) Correctly identifies claim + task
#   - (1) Diagnoses the main perception/encoding issue
#   - (1) Proposes concrete redesign fixes
# - **Synthesis + summary + references (5 pts):**
#   - Rules of thumb are actionable
#   - Summary table is complete
#   - References are in APA format

# %% [markdown]
# # References (APA)
#
# Centers for Disease Control and Prevention. (2026). *Long-term care influenza hospitalization rate among residents, reported to NHSN, national summary, 2025–2026 season* [Chart]. CDC FluView. Retrieved January 24, 2026, from https://www.cdc.gov/fluview/media/images/2026/01/LTCF02.gif
#
# NASA Science. (2025). *2025 global temperature anomalies (GISTEMP)* [Image]. NASA. Retrieved January 24, 2026, from https://assets.science.nasa.gov/dynamicimage/assets/science/esd/indicators/global-temperature/GISTEMP_Map_HD_2025.webp
#
# National Drought Mitigation Center. (2026, January 22). *U.S. Drought Monitor (January 20, 2026)* [Map]. University of Nebraska–Lincoln. https://droughtmonitor.unl.edu/data/png/20260120/20260120_usdm.png
#
# National Hurricane Center. (n.d.). *Tropical cyclone track and watches/warnings: Cone of uncertainty example* [Image]. National Oceanic and Atmospheric Administration. Retrieved January 24, 2026, from https://www.nhc.noaa.gov/images/cone_5day_with_wind.png
#
# Wellcome Collection. (n.d.). *Army in the East* [Chart image]. In *Mortality of the British army: at home and abroad, and during the Russian war, as compared with the mortality of the civil population in England; illustrated by tables and diagrams* (Wellcome Collection item b20452433, plate b20452433_0050). Retrieved January 24, 2026, from https://wellcomecollection.org/works/gxtkyqp8
